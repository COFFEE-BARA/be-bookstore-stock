# %%
from geopy.geocoders import Nominatim
import requests
from bs4 import BeautifulSoup

# %%
def geocoding(address):
    geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
    geo = geolocoder.geocode(address)
    crd = {"lat": str(geo.latitude), "lng": str(geo.longitude)}

    return crd


crd = geocoding("서울특별시 종로구 청계천로 41")
print(crd['lat']) # 위도
print(crd['lng']) # 경도

# %%
crd = geocoding("서울특별시 종로구 청계천로 41")
print(crd['lat']) # 위도
print(crd['lng']) # 경도
# Out:
# 37.5699671
# 127.0126179

# %%
import re

url = 'https://www.ypbooks.co.kr/m_store.yp'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html>
# <head>
# <meta content="width=device-width, user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta charset="utf-8"/>
# <title>영풍문고</title>
# <noscript><meta content="0; URL=http://www.ypbooks.co.kr/noscript.html" http-equiv="refresh"/></noscript>
# <link href="/ypbooks_mobile/css/styleGroup.css" rel="stylesheet"/>
# <link href="/ypbooks_mobile/css/style.min.css" rel="stylesheet"/>
# <link href="/ypbooks_mobile/css/yp.plugin.min.css" rel="stylesheet"/>
# <script src="/ypbooks_mobile/js/jquery-1.12.4.min.js"></script>
# <script src="/ypbooks_mobile/js/jquery-migrate-1.2.1.min.js"></script>
# <script src="/ypbooks_mobile/js/jquery.cookie.min.js"></script>
# <script src="/ypbooks_mobile/js/jquery.fitvids.js"></script>
# <script src="/ypbooks_mobile/js/jquery.bxslider.min.js"></script>
# <script src="/ypbooks_mobile/js/yp.plugin.min.js"></script>
# ...

# %%
store_links = soup.find_all('a')

# %%
store_dict = {}
for link in store_links:
    store_name = link.get_text().strip()
    
    branch_cd = re.search('branchCD=(\d+)', link['href']).group(1)
    
    store_dict[store_name] = branch_cd

# %%
store_dict
# Out:
# {'종각 종로본점': '2000',
#  '스타필드 코엑스몰점': '3600',
#  '강남역점': '3700',
#  '여의도 IFC몰점': '3500',
#  '김포공항 롯데점': '5800',
#  '홍대점': '4700',
#  '가산 마리오점': '4900',
#  '강남 포스코점': '8260',
#  '용산아이파크몰점': '6750',
#  '왕십리역점': '3050',
#  '신림 타임스트림점': '3060',
#  '미아 롯데점': '5250',
#  '사당역점': '3080',
#  '인천 터미널점': '2200',
#  '수원 NC점': '2800',
#  '의정부 신세계점': '6400',
#  '죽전 이마트점': '7100',
#  '스타필드 하남점': '6500',
#  '분당 서현점': '4500',
#  '스타필드 고양점': '6700',
#  '인천 스퀘어원점': '8800',
#  '스타필드시티 위례점': '6770',
#  '구리 롯데아울렛점': '6780',
#  '스타필드 안성점': '6790',
#  '동탄 롯데점': '4400',
#  '스타필드 수원점': '7500',
#  '세종이마트점': '8300',
#  '천안점': '8250',
#  '대전 터미널점': '3400',
#  '청주점': '8200',
#  '유성점': '8400',
#  '경산 이마트점': '7300',
#  '구미 롯데마트점': '4600',
#  '대구역 롯데점': '8950',
#  '광주 터미널점': '2400',
#  '목포 터미널점': '3300',
#  '전주 터미널점': '3900',
#  '군산 롯데아울렛점': '6760',
#  '광복 롯데점': '5400',
#  '부산대점': '3000',
#  '마산 롯데점': '5300',
#  '부산 남포점': '3800',
#  '부산 하단점': '3070',
#  '센텀시티점': '6800'}

# %%
branch_cd = '3000'

# %%
store_details = {}

# %%
url = f'https://www.ypbooks.co.kr/m_store_view.yp?branchCD={branch_cd}'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'html.parser')

address_dl = soup.find('dt', text='매장주소 :').find_next_sibling('dd')
if address_dl:
    address_li = address_dl.find('li')
    if address_li:
        address = address_li.get_text().strip()

# %%
address_dl = soup.find('dt', text='매장주소 :').find_next_sibling('dd')
if address_dl:
    address_li = address_dl.find('li')
    if address_li:
        address = address_li.get_text().strip()
        print(address)
    else:
        print("주소를 포함하는 <li> 태그가 없습니다.")
else:
    print("매장주소를 포함하는 <dt> 태그가 없습니다.")
# Out:
# 부산광역시 금정구 장전동 40 NC백화점 5층
# /var/folders/d6/d15px6nn599bb66tcmrq23380000gn/T/ipykernel_4249/2825699610.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   address_dl = soup.find('dt', text='매장주소 :').find_next_sibling('dd')

# %%
# 매장명과 주소를 저장할 새로운 딕셔너리
store_address_dict = {}

# store_dict의 각 항목에 대해 주소 정보를 가져옴
for store_name, branch_cd in store_dict.items():
    url = f'https://www.ypbooks.co.kr/m_store_view.yp?branchCD={branch_cd}'
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, 'html.parser')

    address_dl = soup.find('dt', text='매장주소 :').find_next_sibling('dd')
    if address_dl:
        address_li = address_dl.find('li')
        if address_li:
            address = address_li.get_text().strip()
            store_address_dict[store_name] = address
# Out:
# /var/folders/d6/d15px6nn599bb66tcmrq23380000gn/T/ipykernel_4249/1819582562.py:10: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   address_dl = soup.find('dt', text='매장주소 :').find_next_sibling('dd')

# %%
check = {'종각 종로본점': '서울특별시 종로구 청계천로 41',
'스타필드 코엑스몰점': '서울특별시 강남구 삼성동 159',
'강남역점': '서울특별시 강남구 강남대로 408',
'여의도 IFC몰점': '서울특별시 영등포구 여의도동 23-1',
'김포공항 롯데점': '서울특별시 강서구 방화동 886',
'홍대점': '서울특별시 마포구 동교동 159-5',
'가산 마리오점': '서울특별시 금천구 가산동 벚꽃로 266',
'강남 포스코점': '서울시 강남구 테헤란로 440',
'용산아이파크몰점': '서울특별시 용산구 한강로3가 한강대로23길 55',
'왕십리역점': '서울특별시 성동구 왕십리광장로 17',
'신림 타임스트림점': '서울특별시 관악구 신림로 330',
'미아 롯데점': '서울특별시 강북구 도봉로 62',
'사당역점': '서울특별시 서초구 방배천로 11',
'인천 터미널점': '인천광역시 미추홀구 연남로 35',
'수원 NC점': '경기도 수원시 권선구 권선동 1189',
'의정부 신세계점': '경기도 의정부시 평화로 525',
'죽전 이마트점': '경기도 용인시 수지구 포은대로 552',
'스타필드 하남점': '경기도 하남시 미사대로 750',
'분당 서현점': '경기도 성남시 분당구 분당로 55',
'스타필드 고양점': '경기도 고양시 덕양구 고양대로 1955',
'인천 스퀘어원점': '인천광역시 연수구 청능대로 210',
'스타필드시티 위례점': '경기도 하남시 위례대로 200',
'구리 롯데아울렛점': '경기도 구리시 동구릉로136번길 47',
'스타필드 안성점': '경기 안성시 공도읍 서동대로 3930-39',
'동탄 롯데점': '경기도 화성시 동탄역로 160',
'스타필드 수원점': '경기 수원시 장안구 수성로 175',
'세종이마트점': '세종특별자치시 금송로 687',
'천안점': '충청남도 천안시 서북구 쌍용대로 202',
'대전 터미널점': '대전광역시 동구 용전동 68-2',
'청주점': '충청북도 청주시 흥덕구 가경동 1416',
'유성점': '대전광역시 유성구 대학로 60',
'경산 이마트점': '경상북도 경산시 옥산로 227',
'구미 롯데마트점': '경상북도 구미시 구미대로 22길 11',
'대구역 롯데점': '대구광역시 북구 태평로 161',
'광주 터미널점': '광주광역시 서구 광천동 49-1',
'목포 터미널점': '전라남도 목포시 상동 220',
'전주 터미널점': '전라북도 전주시 덕진구 가리내로 70',
'군산 롯데아울렛점': '전라북도 군산시 조촌로 130',
'광복 롯데점': '부산광역시 중구 중앙동7가 20-1',
'부산대점': '부산광역시 금정구 장전동 40',
'마산 롯데점': '경상남도 창원시 마산합포구 신포동2가',
'부산 남포점': '부산광역시 중구 남포동5가 12-1',
'부산 하단점': '부산광역시 사하구 낙동남로 1413',
'센텀시티점': '부산광역시 해운대구 센텀4로 15'}

# %%
def geocoding(address):
    geolocator = Nominatim(user_agent="South Korea", timeout=None)
    location = geolocator.geocode(address)
    if location:
        return {"lat": str(location.latitude), "lng": str(location.longitude)}
    else:
        return {"lat": None, "lng": None}

# %%
test=geocoding('서울특별시 영등포구 여의도동 23')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 test=geocoding('서울특별시 영등포구 여의도동 23')
#
# Cell In[45], line 4, in geocoding(address)
#       2 geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
#       3 geo = geolocoder.geocode(address)
# ----> 4 crd = {"lat": str(geo.latitude), "lng": str(geo.longitude)}
#       5 return crd
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
# 매장 정보를 저장할 리스트
store_info = []

# 각 매장에 대한 정보 추출 및 저장
for branch, address in check.items():
    crd = geocoding(address)
    store_info.append({
        "bookstore": "영풍문고",
        "branch": branch,
        "lati": crd['lat'],
        "long": crd['lng']
    })

# %%
store_info
# Out:
# [{'bookstore': '영풍문고',
#   'branch': '종각 종로본점',
#   'lati': '37.5687294',
#   'long': '126.9950818'},
#  {'bookstore': '영풍문고',
#   'branch': '스타필드 코엑스몰점',
#   'lati': '37.5147838',
#   'long': '127.0543618'},
#  {'bookstore': '영풍문고',
#   'branch': '강남역점',
#   'lati': '37.4915149',
#   'long': '127.0305403'},
#  {'bookstore': '영풍문고', 'branch': '여의도 IFC몰점', 'lati': None, 'long': None},
#  {'bookstore': '영풍문고',
#   'branch': '김포공항 롯데점',
#   'lati': '37.57682',
#   'long': '126.81422'},
#  {'bookstore': '영풍문고',
#   'branch': '홍대점',
#   'lati': '37.5571419',
#   'long': '126.9261901'},
#  {'bookstore': '영풍문고',
#   'branch': '가산 마리오점',
#   'lati': '37.47847565',
#   'long': '126.88518193821237'},
#  {'bookstore': '영풍문고',
#   'branch': '강남 포스코점',
#   'lati': '37.5036201',
#   'long': '127.0456997'},
#  {'bookstore': '영풍문고',
#   'branch': '용산아이파크몰점',
#   'lati': '37.5299526',
#   'long': '126.9648271'},
#  {'bookstore': '영풍문고',
#   'branch': '왕십리역점',
#   'lati': '37.5618981',
# ...

# %%
final = [{'bookstore': '영풍문고',
'branch': '종각 종로본점',
'lati': '37.5687294',
'long': '126.9950818'},
{'bookstore': '영풍문고',
'branch': '스타필드 코엑스몰점',
'lati': '37.5147838',
'long': '127.0543618'},
{'bookstore': '영풍문고',
'branch': '강남역점',
'lati': '37.4915149',
'long': '127.0305403'},
{'bookstore': '영풍문고', 'branch': '여의도 IFC몰점', 'lati': '37.52811', 'long': '126.92608'},
{'bookstore': '영풍문고',
'branch': '김포공항 롯데점',
'lati': '37.57682',
'long': '126.81422'},
{'bookstore': '영풍문고',
'branch': '홍대점',
'lati': '37.5571419',
'long': '126.9261901'},
{'bookstore': '영풍문고',
'branch': '가산 마리오점',
'lati': '37.47847565',
'long': '126.88518193821237'},
{'bookstore': '영풍문고',
'branch': '강남 포스코점',
'lati': '37.5036201',
'long': '127.0456997'},
{'bookstore': '영풍문고',
'branch': '용산아이파크몰점',
'lati': '37.5299526',
'long': '126.9648271'},
{'bookstore': '영풍문고',
'branch': '왕십리역점',
'lati': '37.5618981',
'long': '127.0382167'},
{'bookstore': '영풍문고',
'branch': '신림 타임스트림점',
'lati': '37.48377515',
'long': '126.93014425205124'},
{'bookstore': '영풍문고',
'branch': '미아 롯데점',
'lati': '37.6413735',
'long': '127.0290239'},
{'bookstore': '영풍문고',
'branch': '사당역점',
'lati': '37.477736699999994',
'long': '126.98222323583755'},
{'bookstore': '영풍문고',
'branch': '인천 터미널점',
'lati': '37.4414204',
'long': '126.7027232'},
{'bookstore': '영풍문고',
'branch': '수원 NC점',
'lati': '37.2508559',
'long': '127.0307889'},
{'bookstore': '영풍문고',
'branch': '의정부 신세계점',
'lati': '37.7377035',
'long': '127.0460501'},
{'bookstore': '영풍문고',
'branch': '죽전 이마트점',
'lati': '37.3259847',
'long': '127.1226882'},
{'bookstore': '영풍문고',
'branch': '스타필드 하남점',
'lati': '37.5452385',
'long': '127.2238821'},
{'bookstore': '영풍문고',
'branch': '분당 서현점',
'lati': '37.385305',
'long': '127.1182524'},
{'bookstore': '영풍문고',
'branch': '스타필드 고양점',
'lati': '37.64715785',
'long': '126.89488047318024'},
{'bookstore': '영풍문고',
'branch': '인천 스퀘어원점',
'lati': '37.406571',
'long': '126.6856005'},
{'bookstore': '영풍문고',
'branch': '스타필드시티 위례점',
'lati': '37.4803741',
'long': '127.1485502'},
{'bookstore': '영풍문고',
'branch': '구리 롯데아울렛점',
'lati': '37.611867',
'long': '127.1405433'},
{'bookstore': '영풍문고',
'branch': '스타필드 안성점',
'lati': '36.994437',
'long': '127.1473048'},
{'bookstore': '영풍문고',
'branch': '동탄 롯데점',
'lati': '37.2003887',
'long': '127.0974134'},
{'bookstore': '영풍문고',
'branch': '스타필드 수원점',
'lati': '37.2913721',
'long': '127.0054572'},
{'bookstore': '영풍문고',
'branch': '세종이마트점',
'lati': '36.4708801',
'long': '127.25100348035954'},
{'bookstore': '영풍문고',
'branch': '천안점',
'lati': '36.8280904',
'long': '127.1376521'},
{'bookstore': '영풍문고',
'branch': '대전 터미널점',
'lati': '36.353219',
'long': '127.4341323'},
{'bookstore': '영풍문고',
'branch': '청주점',
'lati': '36.6200658',
'long': '127.4341467'},
{'bookstore': '영풍문고',
'branch': '유성점',
'lati': '36.3553474',
'long': '127.3420074'},
{'bookstore': '영풍문고',
'branch': '경산 이마트점',
'lati': '35.8181021',
'long': '128.727523'},
{'bookstore': '영풍문고', 'branch': '구미 롯데마트점', 'lati': '36.113849', 'long': '128.365350'},
{'bookstore': '영풍문고', 'branch': '대구역 롯데점', 'lati': '35.876089', 'long': '128.595652'},
{'bookstore': '영풍문고',
'branch': '광주 터미널점',
'lati': '35.1647499',
'long': '126.8810106'},
{'bookstore': '영풍문고',
'branch': '목포 터미널점',
'lati': '34.8080793',
'long': '126.4189568'},
{'bookstore': '영풍문고',
'branch': '전주 터미널점',
'lati': '35.8344956',
'long': '127.12920728936992'},
{'bookstore': '영풍문고',
'branch': '군산 롯데아울렛점',
'lati': '35.9835807',
'long': '126.7376493'},
{'bookstore': '영풍문고',
'branch': '광복 롯데점',
'lati': '35.0973',
'long': '129.03637'},
{'bookstore': '영풍문고',
'branch': '부산대점',
'lati': '35.2335057',
'long': '129.0831656'},
{'bookstore': '영풍문고',
'branch': '마산 롯데점',
'lati': '35.20101',
'long': '128.57316'},
{'bookstore': '영풍문고',
'branch': '부산 남포점',
'lati': '35.09784',
'long': '129.02951'},
{'bookstore': '영풍문고',
'branch': '부산 하단점',
'lati': '35.1063141',
'long': '128.9654347'},
{'bookstore': '영풍문고',
'branch': '센텀시티점',
'lati': '35.1699144',
'long': '129.1283427'}]

# %%
import csv

# CSV 파일로 저장
csv_columns = ['bookstore', 'branch', 'lati', 'long']
csv_file = 'bookstores.csv'

try:
    with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in final:
            writer.writerow(data)
except IOError:
    print("I/O error")

# %%
import pandas as pd

dd = pd.read_csv('./bookstores.csv')

# %%
dd
# Out:
#    bookstore      branch       lati        long
# 0       영풍문고     종각 종로본점  37.568729  126.995082
# 1       영풍문고  스타필드 코엑스몰점  37.514784  127.054362
# 2       영풍문고        강남역점  37.491515  127.030540
# 3       영풍문고   여의도 IFC몰점  37.528110  126.926080
# 4       영풍문고    김포공항 롯데점  37.576820  126.814220
# 5       영풍문고         홍대점  37.557142  126.926190
# 6       영풍문고     가산 마리오점  37.478476  126.885182
# 7       영풍문고     강남 포스코점  37.503620  127.045700
# 8       영풍문고    용산아이파크몰점  37.529953  126.964827
# 9       영풍문고       왕십리역점  37.561898  127.038217
# 10      영풍문고   신림 타임스트림점  37.483775  126.930144
# 11      영풍문고      미아 롯데점  37.641374  127.029024
# 12      영풍문고        사당역점  37.477737  126.982223
# 13      영풍문고     인천 터미널점  37.441420  126.702723
# 14      영풍문고      수원 NC점  37.250856  127.030789
# 15      영풍문고    의정부 신세계점  37.737704  127.046050
# 16      영풍문고     죽전 이마트점  37.325985  127.122688
# 17      영풍문고    스타필드 하남점  37.545239  127.223882
# 18      영풍문고      분당 서현점  37.385305  127.118252
# ...
